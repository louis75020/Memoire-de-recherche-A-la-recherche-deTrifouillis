# %% [markdown]
# # Boosted Gradient:Levenshtein

# %%
# %pylab inline

#For data
import pandas as pd

#For modelling
import xgboost as xgb
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import Levenshtein as lev
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Importation of data

# %%
communes_dataframe = pd.read_csv("COMMUNES.csv", delimiter=";")
communes_dataframe
# Out:
#        insee                       nom  altitude  code_postal  longitude  \
# 0       1001   L'Abergement-Clémenciat     257.0         1400   0.085856
# 1       1002     L'Abergement-de-Varey     367.0         1640   0.094665
# 2       1004         Ambérieu-en-Bugey     247.0         1500   0.093356
# 3       1005       Ambérieux-en-Dombes     293.0         1330   0.085594
# 4       1006                   Ambléon     400.0         1300   0.097777
# 5       1007                  Ambronay     250.0         1500   0.093540
# 6       1008                  Ambutrix     270.0         1500   0.093239
# 7       1009          Andert-et-Condon     330.0         1300   0.098718
# 8       1010                 Anglefort     250.0         1350   0.101384
# 9       1011                  Apremont     900.0         1100   0.098849
# 10      1012                     Aranc     781.0         1110   0.096124
# 11      1013                   Arandas     740.0         1230   0.095799
# 12      1014                    Arbent     560.0         1100   0.099110
# 13      1015                 Arbignieu     280.0         1300   0.098626
# 14      1016                   Arbigny     200.0         1190   0.086767
# 15      1017                     Argis     320.0         1230   0.095843
# 16      1019                     Armix     721.0         1510   0.097501
# 17      1021           Ars-sur-Formans     250.0         1480   0.084149
# 18      1022                  Artemare     260.0         1510   0.099387
# 19      1023        Asnières-sur-Saône     174.0         1570   0.085216
# 20      1024                  Attignat     222.0         1340   0.090078
# 21      1025             Bâgé-la-Ville     210.0         1380   0.086311
# 22      1026            Bâgé-le-Châtel     205.0         1380   0.086030
# 23      1027                     Balan     194.0         1360   0.089007
# 24      1028                   Baneins     240.0         1990   0.085608
# 25      1029                  Beaupont     210.0         1270   0.091882
# 26      1030                Beauregard     180.0         1480   0.082927
# 27      1031                 Bellignat     526.0  01810|01100   0.098214
# 28      1032                 Béligneux     250.0         1360   0.089526
# 29      1033  Bellegarde-sur-Valserine     350.0         1200   0.101549
# ...      ...                       ...       ...          ...        ...
# 36179  95574                Saint-Prix     130.0        95390   0.039493
# 36180  95580                Saint-Witz     168.0        95470   0.044836
# 36181  95582                   Sannois      56.0        95110   0.039372
# 36182  95584                  Santeuil      80.0        95640   0.034111
# 36183  95585                 Sarcelles      68.0        95200   0.041495
# 36184  95592               Seraincourt      40.0        95450   0.032604
# 36185  95594                     Seugy      78.0        95270   0.041772
# 36186  95598    Soisy-sous-Montmorency      44.0        95230   0.040162
# 36187  95604               Survilliers     140.0        95470   0.044390
# 36188  95607                   Taverny      90.0        95150   0.038838
# 36189  95610              Théméricourt      80.0        95450   0.033142
# 36190  95611                 Theuville      90.0        95810   0.036196
# 36191  95612                Le_Thillay      80.0        95500   0.043153
# 36192  95625                        Us     110.0        95450   0.034335
# 36193  95627             Vallangoujard      57.0        95810   0.036914
# 36194  95628                Valmondois      33.0        95760   0.038257
# 36195  95633               Vaudherland      73.0        95500   0.043396
# 36196  95637                   Vauréal      40.0        95490   0.035454
# 36197  95641                    Vémars     120.0        95470   0.044860
# 36198  95651                  Vétheuil      20.0  95780|95510   0.029753
# 36199  95652                   Viarmes      50.0        95270   0.041384
# 36200  95656         Vienne-en-Arthies      69.0        95510   0.030281
# 36201  95658                     Vigny      70.0        95450   0.033670
# 36202  95660       Villaines-sous-Bois     120.0        95570   0.041156
# 36203  95675                  Villeron     110.0        95380   0.044380
# 36204  95676        Villers-en-Arthies     150.0        95510   0.030136
# 36205  95678             Villiers-Adam     130.0        95840   0.039013
# 36206  95680           Villiers-le-Bel     104.0        95400   0.041699
# 36207  95682           Villiers-le-Sec     130.0        95720   0.041728
# 36208  95690       Wy-dit-Joli-Village     125.0        95420   0.032027
#
#        latitude  pop99  surface  departement region  indicatif
# 0      0.805508    728    15.70            1     RA          4
# 1      0.802987    168     9.14            1     RA          4
# 2      0.802085  11436    24.51            1     RA          4
# 3      0.802784   1408    16.06            1     RA          4
# 4      0.798493     86     6.03            1     RA          4
# 5      0.802992   2146    33.64            1     RA          4
# 6      0.801795    586     5.19            1     RA          4
# 7      0.799283    275     6.95            1     RA          4
# 8      0.801315    769    29.49            1     RA          4
# 9      0.806517    329    15.09            1     RA          4
# 10     0.802944    275    21.76            1     RA          4
# 11     0.801043    135    14.05            1     RA          4
# 12     0.808010   3610    23.78            1     RA          4
# 13     0.798125    431    13.04            1     RA          4
# 14     0.811084    332    17.48            1     RA          4
# 15     0.801712    390     7.90            1     RA          4
# 16     0.800224     15     6.95            1     RA          4
# 17     0.802764   1102     5.57            1     RA          4
# 18     0.800655    970     3.34            1     RA          4
# 19     0.809527     69     4.70            1     RA          4
# 20     0.807913   1924    18.97            1     RA          4
# 21     0.808359   2314    39.85            1     RA          4
# 22     0.808233    762     0.89            1     RA          4
# 23     0.799952   1534    17.94            1     RA          4
# 24     0.804805    529     9.06            1     RA          4
# 25     0.810012    492    14.06            1     RA          4
# 26     0.802924    817     0.95            1     RA          4
# 27     0.807084   3488     7.79            1     RA          4
# 28     0.800534   2594    13.30            1     RA          4
# 29     0.804849  10846    15.51            1     RA          4
# ...         ...    ...      ...          ...    ...        ...
# 36179  0.855371   6767     7.91           95     IF          1
# 36180  0.856816   1925     7.56           95     IF          1
# 36181  0.854770  25349     4.78           95     IF          1
# 36182  0.857398    578     5.35           95     IF          1
# 36183  0.855206  57871     8.40           95     IF          1
# 36184  0.855832   1261    11.33           95     IF          1
# 36185  0.857296   1049     1.70           95     IF          1
# 36186  0.854998  16802     3.96           95     IF          1
# 36187  0.856899   3654     5.41           95     IF          1
# 36188  0.855599  25909    10.42           95     IF          1
# 36189  0.856705    229     7.51           95     IF          1
# 36190  0.857892     59     5.05           95     IF          1
# 36191  0.855318   3665     3.98           95     IF          1
# 36192  0.856971   1253    10.98           95     IF          1
# 36193  0.857606    635     7.53           95     IF          1
# 36194  0.856860   1213     4.53           95     IF          1
# 36195  0.855236     88     0.10           95     IF          1
# 36196  0.855817  16206     3.75           95     IF          1
# 36197  0.856428   2058     8.35           95     IF          1
# 36198  0.856302    858     4.47           95     IF          1
# 36199  0.857403   4681     8.26           95     IF          1
# 36200  0.856375    352     3.78           95     IF          1
# 36201  0.856554   1036     6.82           95     IF          1
# 36202  0.856520    583     1.90           95     IF          1
# 36203  0.856191    702     5.72           95     IF          1
# 36204  0.856763    426     8.43           95     IF          1
# 36205  0.856312    775     9.89           95     IF          1
# 36206  0.855313  26145     7.27           95     IF          1
# 36207  0.856457    168     3.21           95     IF          1
# 36208  0.857025    307     8.44           95     IF          1
#
# [36209 rows x 11 columns]

# %% [markdown]
# ## Preparation of data

# %% [markdown]
# ### Creation of medians/region

# %%
ALL_COMMUNES=communes_dataframe.values
ALL_COMMUNES[where(ALL_COMMUNES[:,10]==1)]
# Out:
# array([[75056, 'Paris', 60.0, ..., 75, 'IF', 1],
#        [77001, 'Achères-la-Forêt', 110.0, ..., 77, 'IF', 1],
#        [77002, 'Amillis', 110.0, ..., 77, 'IF', 1],
#        ...,
#        [95680, 'Villiers-le-Bel', 104.0, ..., 95, 'IF', 1],
#        [95682, 'Villiers-le-Sec', 130.0, ..., 95, 'IF', 1],
#        [95690, 'Wy-dit-Joli-Village', 125.0, ..., 95, 'IF', 1]],
#       dtype=object)

# %%
COMMUNES, TEST_COMMUNES = train_test_split(ALL_COMMUNES, test_size=0.099, random_state=10)

# %%
lev.median(['lille','mille','chilo'])
# Out:
# 'cille'

# %%
#set(ALL_COMMUNES[:,9])

# %%
def median_per_region(INPUT=COMMUNES,SET=True,Improved=10):
    
    OUTPUT=[]
    regions=set(INPUT[:,9])
    
    for i in regions:
        
        print('current region ',i)
        tmp=INPUT[where(INPUT[:,9]==i)]
        tmp2=tmp[:,1]
        
        if SET: median=lev.setmedian(tmp2)
        else: median=lev.median(tmp2)
            
        print('The median is ',median)
        
        
        if Improved>0:
            improve_median=lev.median_improve(median,tmp2)
            for j in range(10):
                improve_median=lev.median_improve(improve_median,tmp2)
            print('The improved median is ',improve_median)
            median=improve_median
        
        OUTPUT.append(median)
        print('\n','--------------')
        
    return OUTPUT

print(COMMUNES[0:5,:],'\n','--------------')
median_per_region(COMMUNES[0:5,:])
# Out:
# [[72163 'Ligron' 95.0 '72270' 0.00012119565958728001 0.833801981737 358
#   13.67 72 'PL' 2]
#  [67456 'Schopperten' 220.0 '67260' 0.12305056754116 0.8542513970623 292
#   4.42 67 'AL' 3]
#  [27588 "Saint-Pierre-d'Autils" 20.0 '27950' 0.025084256050807996
#   0.8572960559785301 1036 7.18 27 'HN' 2]
#  [60264 'Frocourt' 87.0 '60000' 0.03638526362326 0.86188235227079 514
#   6.49 60 'PI' 3]
#  [77496 'Vieux-Champagne' 130.0 '77370' 0.054793636450322994
#   0.8479003570737099 190 8.89 77 'IF' 1]]
#  --------------
# current region  HN
# The median is  Saint-Pierre-d'Autils
# The improved median is  Saint-Pierre-d'Autils
#
#  --------------
# current region  PI
# The median is  Frocourt
# The improved median is  Frocourt
#
#  --------------
# current region  AL
# The median is  Schopperten
# The improved median is  Schopperten
#
#  --------------
# current region  IF
# The median is  Vieux-Champagne
# The improved median is  Vieux-Champagne
#
#  --------------
# current region  PL
# The median is  Ligron
# The improved median is  Ligron
#
#  --------------
# ["Saint-Pierre-d'Autils",
#  'Frocourt',
#  'Schopperten',
#  'Vieux-Champagne',
#  'Ligron']

# %%
medians=median_per_region()
# Out:
# current region  PI
# The median is  Maulers
# The improved median is  aineure
#
#  --------------
# current region  BN
# The median is  Banville
# The improved median is  Saneil-e
#
#  --------------
# current region  BO
# The median is  Saules
# The improved median is  aines
#
#  --------------
# current region  PA
# The median is  Sannes
# The improved median is  Saines
#
#  --------------
# current region  CA
# The median is  Caurel
# The improved median is  aie-ure
#
#  --------------
# current region  RA
# The median is  Baneins
# The improved median is  San-ene
#
#  --------------
# current region  BR
# The median is  Santec
# The improved median is  Lan-en
#
#  --------------
# current region  AL
# The median is  Biesheim
# The improved median is  iesheie
#
#  --------------
# current region  PC
# The median is  Saintes
# The improved median is  Sainae
#
#  --------------
# current region  HN
# The median is  Barville
# The improved median is  aineille
#
#  --------------
# current region  LO
# The median is  Barville
# The improved median is  aenilre
#
#  --------------
# current region  MP
# The median is  Mauran
# The improved median is  Saneae
#
#  --------------
# current region  AQ
# The median is  Barie
# The improved median is  Sainae
#
#  --------------
# current region  IF
# The median is  Marines
# The improved median is  aine-re
#
#  --------------
# current region  LR
# The median is  Carnas
# The improved median is  Saie-es
#
#  --------------
# current region  LI
# The median is  Saint-Jal
# The improved median is  Saine-ae
#
#  --------------
# current region  CE
# The median is  Santeau
# The improved median is  eain-e
#
#  --------------
# current region  NP
# The median is  Harnes
# The improved median is  eaines
#
#  --------------
# current region  FC
# The median is  Verne
# The improved median is  aoeane
#
#  --------------
# current region  PL
# The median is  Conlie
# The improved median is  aine-ae
#
#  --------------
# current region  AU
# The median is  Saignes
# The improved median is  Saintes
#
#  --------------

# %% [markdown]
# ## Calculation of the distances betwenn cities and medians

# %%
def lev_data(INPUT=COMMUNES,B=True,medians=medians):
    
    DATA=INPUT[:,1]
    OUTPUT=[]
    
    for s in DATA:
        
        tmp=[]
        
        for m in medians:
        
            if(B):tmp.append(lev.distance(s,m))
            
            else:tmp.append(lev.jaro(s,m))
            
        OUTPUT.append(array(tmp))
        
    return array(OUTPUT)

lev_data(COMMUNES[1:5,:])
# Out:
# array([[ 9,  9, 10,  9,  9,  8,  9,  9,  9, 10,  9,  8,  9,  9,  8,  8,
#         10, 10,  8,  9,  8],
#        [15, 16, 16, 15, 16, 15, 17, 17, 16, 16, 16, 16, 16, 15, 15, 15,
#         16, 16, 18, 16, 14],
#        [ 6,  8,  8,  8,  6,  8,  8,  8,  8,  8,  7,  8,  8,  7,  8,  8,
#          8,  8,  7,  8,  8],
#        [12, 13, 13, 13, 11, 12, 13, 11, 12, 13, 13, 12, 12, 12, 13, 12,
#         12, 12, 11, 11, 14]])

# %%
lev_data(COMMUNES[1:5,:],False)
# Out:
# array([[0.56709957, 0.54924242, 0.43030303, 0.50505051, 0.56709957,
#         0.56709957, 0.41919192, 0.56709957, 0.50505051, 0.47727273,
#         0.32251082, 0.50505051, 0.50505051, 0.56709957, 0.56709957,
#         0.54924242, 0.41919192, 0.41919192, 0.50505051, 0.48917749,
#         0.45598846],
#        [0.58412698, 0.62301587, 0.58095238, 0.61904762, 0.58412698,
#         0.65079365, 0.54761905, 0.41269841, 0.69047619, 0.62103175,
#         0.51746032, 0.61904762, 0.69047619, 0.65873016, 0.65079365,
#         0.68849206, 0.69047619, 0.54761905, 0.54761905, 0.65079365,
#         0.71428571],
#        [0.3452381 , 0.        , 0.        , 0.        , 0.3452381 ,
#         0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.42261905, 0.        , 0.        , 0.42261905, 0.        ,
#         0.        , 0.        , 0.        , 0.43055556, 0.        ,
#         0.42261905],
#        [0.54285714, 0.41388889, 0.51111111, 0.48888889, 0.52936508,
#         0.30634921, 0.32222222, 0.54285714, 0.48888889, 0.46111111,
#         0.30634921, 0.41111111, 0.48888889, 0.54285714, 0.54285714,
#         0.58888889, 0.45555556, 0.32222222, 0.41111111, 0.61269841,
#         0.47301587]])

# %%
X_lev_train=lev_data(COMMUNES)
X_lev_test=lev_data(TEST_COMMUNES)

X_jaro_train=lev_data(COMMUNES,False)
X_jaro_test=lev_data(TEST_COMMUNES,False)

shape(X_jaro_test)
# Out:
# (3585, 21)

# %%
def response_initialization(INPUT):
    
    #print(INPUT)
    
    i=1
    OUTPUT=INPUT
    TMP=[]
    
    for e in INPUT:
        
        if TMP.count(e)<= 0: TMP.append(e)
            
    #print(TMP)
    
    for e in TMP:
            
            OUTPUT[where(OUTPUT==e)]=i
            i+=1
        
    return OUTPUT

# %%
Y_train=response_initialization(COMMUNES[:,9])
Y_test=response_initialization(TEST_COMMUNES[:,9])
shape(Y_test)
# Out:
# (3585,)

# %%
dtrain_lev=xgb.DMatrix(X_lev_train,Y_train)
dtest_lev=xgb.DMatrix(X_lev_test,Y_test)

dtrain_jaro=xgb.DMatrix(X_jaro_train,Y_train)
dtest_jaro=xgb.DMatrix(X_jaro_test,Y_test)
# Out:
# C:\Users\louis\Anaconda3\lib\site-packages\xgboost\core.py:384: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "memory consumption")

# %% [markdown]
# ## Model creation

# %%
params = {'booster':'gbtree','objective': 'multi:softprob','num_class':22,'eval_metric':'mlogloss','max_depth':3,'nthread':10}

# %%
evallist = [(dtest_lev, 'eval'), (dtrain_lev, 'train')]
num_round = 500

xg_tree=xgb.train(params, dtrain_lev, num_round,evallist,early_stopping_rounds=10)
# Out:
# [0]	eval-mlogloss:3.09034	train-mlogloss:3.04148
# Multiple eval metrics have been passed: 'train-mlogloss' will be used for early stopping.
#
# Will train until train-mlogloss hasn't improved in 10 rounds.
# [1]	eval-mlogloss:3.09285	train-mlogloss:3.00502
# [2]	eval-mlogloss:3.09771	train-mlogloss:2.97857
# [3]	eval-mlogloss:3.10522	train-mlogloss:2.95817
# [4]	eval-mlogloss:3.11278	train-mlogloss:2.94100
# [5]	eval-mlogloss:3.12047	train-mlogloss:2.92720
# [6]	eval-mlogloss:3.12747	train-mlogloss:2.91594
# [7]	eval-mlogloss:3.13452	train-mlogloss:2.90536
# [8]	eval-mlogloss:3.14114	train-mlogloss:2.89687
# [9]	eval-mlogloss:3.14777	train-mlogloss:2.88995
# [10]	eval-mlogloss:3.15388	train-mlogloss:2.88293
# [11]	eval-mlogloss:3.15917	train-mlogloss:2.87661
# [12]	eval-mlogloss:3.16439	train-mlogloss:2.87119
# [454]	eval-mlogloss:3.52418	train-mlogloss:2.35355
# [455]	eval-mlogloss:3.52492	train-mlogloss:2.35288
# [456]	eval-mlogloss:3.52509	train-mlogloss:2.35231
# [457]	eval-mlogloss:3.52529	train-mlogloss:2.35154
# [458]	eval-mlogloss:3.52583	train-mlogloss:2.35098
# [459]	eval-mlogloss:3.52658	train-mlogloss:2.35027
# [460]	eval-mlogloss:3.52706	train-mlogloss:2.34972
# [461]	eval-mlogloss:3.52775	train-mlogloss:2.34905
# [462]	eval-mlogloss:3.52827	train-mlogloss:2.34841
# [463]	eval-mlogloss:3.52907	train-mlogloss:2.34777
# [464]	eval-mlogloss:3.52991	train-mlogloss:2.34698
# [465]	eval-mlogloss:3.53089	train-mlogloss:2.34624
# [466]	eval-mlogloss:3.53149	train-mlogloss:2.34550
# [467]	eval-mlogloss:3.53251	train-mlogloss:2.34468
# [468]	eval-mlogloss:3.53263	train-mlogloss:2.34397
# [469]	eval-mlogloss:3.53354	train-mlogloss:2.34325
# [470]	eval-mlogloss:3.53402	train-mlogloss:2.34245
# [471]	eval-mlogloss:3.53441	train-mlogloss:2.34175
# [472]	eval-mlogloss:3.53486	train-mlogloss:2.34097
# [473]	eval-mlogloss:3.53549	train-mlogloss:2.34021
# [474]	eval-mlogloss:3.53600	train-mlogloss:2.33950
# [475]	eval-mlogloss:3.53663	train-mlogloss:2.33878
# [476]	eval-mlogloss:3.53764	train-mlogloss:2.33808
# [477]	eval-mlogloss:3.53799	train-mlogloss:2.33743
# [478]	eval-mlogloss:3.53826	train-mlogloss:2.33667
# [479]	eval-mlogloss:3.53865	train-mlogloss:2.33603
# [480]	eval-mlogloss:3.53922	train-mlogloss:2.33543
# [481]	eval-mlogloss:3.53953	train-mlogloss:2.33483
# [482]	eval-mlogloss:3.53993	train-mlogloss:2.33412
# [483]	eval-mlogloss:3.54074	train-mlogloss:2.33336
# [484]	eval-mlogloss:3.54142	train-mlogloss:2.33271
# [485]	eval-mlogloss:3.54195	train-mlogloss:2.33224
# [486]	eval-mlogloss:3.54221	train-mlogloss:2.33154
# [487]	eval-mlogloss:3.54275	train-mlogloss:2.33100
# [488]	eval-mlogloss:3.54293	train-mlogloss:2.33044
# [489]	eval-mlogloss:3.54328	train-mlogloss:2.32970
# [490]	eval-mlogloss:3.54380	train-mlogloss:2.32905
# [491]	eval-mlogloss:3.54420	train-mlogloss:2.32832
# [492]	eval-mlogloss:3.54484	train-mlogloss:2.32765
# [493]	eval-mlogloss:3.54536	train-mlogloss:2.32694
# [494]	eval-mlogloss:3.54555	train-mlogloss:2.32637
# [495]	eval-mlogloss:3.54556	train-mlogloss:2.32560
# [496]	eval-mlogloss:3.54609	train-mlogloss:2.32483
# [497]	eval-mlogloss:3.54665	train-mlogloss:2.32418
# [498]	eval-mlogloss:3.54713	train-mlogloss:2.32342
# [499]	eval-mlogloss:3.54740	train-mlogloss:2.32271

# %%
xg_tree.attributes()
# Out:
# {'best_iteration': '499',
#  'best_msg': '[499]\teval-mlogloss:3.54740\ttrain-mlogloss:2.32271',
#  'best_score': '2.322708'}
